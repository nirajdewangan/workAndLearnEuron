# %%
l=[2,3,4,5,6]

# %%
for i in l:
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
for i in l:
    print(i+1)
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
l1 = [] 
for i in l:
    print(i+1)
    l1.append(i+1)
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
l1
# Out:
# [3, 4, 5, 6, 7]
