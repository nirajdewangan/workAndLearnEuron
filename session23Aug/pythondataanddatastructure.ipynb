# %%
s = "euron system"

# %%
type(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 type(a)
#       2
#
# NameError: name 'a' is not defined

# %%
type(s)
# Out:
# str

# %%
s.upper()
# Out:
# 'EURON SYSTEM'

# %%
s.capitalize()
# Out:
# 'Euron system'

# %%
s.count("e")
# Out:
# 2

# %%
s.count("eu")
# Out:
# 1

# %%
s.find('u')
# Out:
# 1

# %%
s.index('e')
# Out:
# 0

# %%
s.index('z')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 s.index('z')
#
# ValueError: substring not found

# %%
s.find('z')
# Out:
# -1

# %%
s.split()
# Out:
# ['euron', 'system']

# %%
s.split(sep='e')
# Out:
# ['', 'uron syst', 'm']

# %%
l = [2,3,4,5,6,"sudh"]

# %%
l.append([3,4,5])

# %%
l
# Out:
# [2, 3, 4, 5, 6, 'sudh', [3, 4, 5]]

# %%
l.extend("sudh")

# %%
l
# Out:
# [2, 3, 4, 5, 6, 'sudh', [3, 4, 5], 's', 'u', 'd', 'h']

# %%
l = [2,3,4,5,6,"sudh"]

# %%
l.insert(2,(3,4,56))

# %%
l
# Out:
# [2, 3, (3, 4, 56), 4, 5, 6, 'sudh']

# %%
l.pop(9)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 l.pop(9)
#
# IndexError: pop index out of range

# %%
l.pop()
# Out:
# 'sudh'

# %%
l.pop(1)
# Out:
# 3

# %%
l.remove("sudh")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 l.remove("sudh")
#
# ValueError: list.remove(x): x not in list

# %%
l.remove(4)

# %%
l
# Out:
# [2, (3, 4, 56), 5, 6]

# %%
l.count(2)
# Out:
# 1

# %%
l.reverse()

# %%
l
# Out:
# [6, 5, (3, 4, 56), 2]

# %%
l[0]="sudh"

# %%
l
# Out:
# ['sudh', 5, (3, 4, 56), 2]

# %%
l = [3,4,5,6,true]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 l = [3,4,5,6,true]
#
# NameError: name 'true' is not defined

# %%
l = [3,4,5,6,True]

# %%
l
# Out:
# [3, 4, 5, 6, True]

# %%
l1 = l

# %%
l2 = l.copy()

# %%
l['euron']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 l['euron']
#
# TypeError: list indices must be integers or slices, not str

# %%
l[0] = 'euron'

# %%
l1
# Out:
# ['euron', 4, 5, 6, True]

# %%
l2
# Out:
# [3, 4, 5, 6, True]
