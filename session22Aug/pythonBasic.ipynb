# %%
1+1
# Out:
# 2

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
b = 3.14
type(b)
c = "Hello, World!"
type(c)
c1 = 'Hello, World!'
type(c1)
c2 = """Hello, World!"""
type(c2)
d = 4+5j    
type(d) 
e = True
type(e) 
True- False
# Out:
# 1

# %%
l = [3,4,5,6,7,"Hello, World!"]

# %%
l
# Out:
# [3, 4, 5, 6, 7, 'Hello, World!']

# %%
type(l)
# Out:
# list

# %%
t= (3,4,5,6,7,"Hello, World!")

# %%
type(t )
# Out:
# tuple

# %%
s = {3,4,5,6,7,"Hello, World!"}

# %%
s
# Out:
# {3, 4, 5, 6, 7, 'Hello, World!'}

# %%
type(s)
# Out:
# set

# %%
obj = {"name":"Niraj", "age": 25, "city": "New York"}
type(obj)
# Out:
# dict

# %%
t =
