# %%
transactions = [1200, 450, 800, 1500, 2300, 700, 100]

# %%
total = 0

# %%
for transaction in transactions:
    total += transaction
print("total:", total)
# Out:
# total: 7050

# %%
highest = transactions[0]
lowest = transactions[0]

for transaction in transactions:
    if transaction > highest:
        highest = transaction
    elif transaction < lowest:
        lowest = transaction
print("highest:", highest)
print("lowest:", lowest)
# Out:
# highest: 2300
# lowest: 100

# %%
temperatures = [32, 35, 28, 40, 38, 31, 42]

# %%
total_temperature = 0
for temperature in temperatures:
    total_temperature += temperature

    average_temperature = total_temperature / len(temperatures)
print("average temperature:", average_temperature)
# Out:
# average temperature: 35.142857142857146

# %%
marks = [78, 92, 45, 67, 88, 53, 99]

# %%
above_90 = 0
between_75_89 = 0
between_50_74 = 0
below_50 = 0

# %%
for mark in marks:
    if mark > 90:
        above_90 += 1
    elif 75 <= mark <= 89:
        between_75_89 += 1
    elif 50 <= mark <= 74:
        between_50_74 += 1
    else:
        below_50 += 1

print("Number of students with marks above 90:", above_90)
print("Number of students with marks between 75 and 89:", between_75_89)
print("Number of students with marks between 50 and 74:", between_50_74)
print("Number of students with marks below 50:", below_50)
# Out:
# Number of students with marks above 90: 2
# Number of students with marks between 75 and 89: 2
# Number of students with marks between 50 and 74: 2
# Number of students with marks below 50: 1

# %%
correct_password = "secure123"

# %%
for attempt in range(1,4):
    password = input("Enter the password: ")
    if password == correct_password:
        print("Login successful!")
        break
    else:
        print("Incorrect password. Try again.")
        remaining_attempts = 3 - attempt
        if remaining_attempts > 0:
            print(f"You have {remaining_attempts} attempts left.")
else:
    print("Too many failed attempts. Access denied.")
# Out:
# Incorrect password. Try again.
# You have 2 attempts left.
# Incorrect password. Try again.
# You have 1 attempts left.
# Incorrect password. Try again.
# Too many failed attempts. Access denied.

# %%
products = {
    "Laptop": 55000,
    "Phone": 30000,
    "Headphones": 2000,
    "Mouse": 700,
    "Keyboard": 1500
}

for product, price in products.items():
    if price > 2000:
        print(f"{product}: {price}")
# Out:
# Laptop: 55000
# Phone: 30000

# %%
numbers = []
for i in range(10):
    number = int(input(f"Enter number {i+1}: "))
    numbers.append(number)
print("You entered:", numbers)
# Out:
# You entered: [1, 2, 2, 3, 4, 4, 4, 5, 55, 5]

# %%
text = input("Enter a string: ")
frequency = {}

for char in text:
    if char in frequency:
        frequency[char] += 1
    else:
        frequency[char] = 1

print("Character frequencies:")
for char, freq in frequency.items():
    print(f"{char}: {freq}")
# Out:
# Character frequencies:
# b: 1
# a: 3
# n: 2

# %%
numbers = [10, 45, 23, 67, 67, 34, 56]
largest = None
second_largest = None

for number in numbers:
    if largest is None or number > largest:
        second_largest = largest
        largest = number
    elif second_largest is None or (number > second_largest and number != largest):
        second_largest = number

print("Largest:", largest)
print("Second Largest:", second_largest)
# Out:
# Largest: 67
# Second Largest: 56

# %%
text = input("Enter a string: ")

is_palindrome = True

left = 0
right = len(text) - 1

while left < right:
    if text[left] != text[right]:
        is_palindrome = False
        break
    left += 1
    right -= 1

if is_palindrome:
    print("The string is a palindrome.")
else:
    print("The string is not a palindrome.")
# Out:
# The string is not a palindrome.

# %%
# 1
# 12
# 123
# 1234
# 12345

for row in range(1, 6):
    for col in range(1, row + 1):
        print(col, end="")
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
# ATM Simulation

balance = 10000

def check_balance():
    print(f"Your current balance is: ${balance}")

def deposit_money():
    global balance
    amount = float(input("Enter the amount to deposit: "))
    if amount > 0:
        balance += amount
        print(f"${amount} deposited successfully.")
        print(f"New balance: ${balance}")
    else:
        print("Invalid amount. Please enter a positive value.")

def withdraw_money():
    global balance
    amount = float(input("Enter the amount to withdraw: "))
    if 0 < amount <= balance:
        balance -= amount
        print(f"${amount} withdrawn successfully.")
        print(f"New balance: ${balance}")
    else:
        print("Invalid amount. Please enter a positive value not exceeding your balance.")

while True:
    print("\nATM Menu:")
    print("1. Check Balance")
    print("2. Deposit Money")
    print("3. Withdraw Money")
    print("4. Exit")

    choice = input("Enter your choice (1-4): ")

    if choice == '1':
        check_balance()
    elif choice == '2':
        deposit_money()
    elif choice == '3':
        withdraw_money()
    elif choice == '4':
        print("Thank you for using the ATM. Goodbye!")
        break
    else:
        print("Invalid choice. Please select a valid option.")
# Out:
# ATM Menu:
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Your current balance is: $10000
#
# ATM Menu:
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# $1000.0 deposited successfully.
# New balance: $11000.0
#
# ATM Menu:
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# $100.0 withdrawn successfully.
# New balance: $10900.0
#
# ATM Menu:
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Thank you for using the ATM. Goodbye!
