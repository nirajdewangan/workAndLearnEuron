# %%
for number in range(1, 101):
    if number %5 == 0:
        continue
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 11
# 12
# 13
# 14
# 16
# 17
# 18
# 19
# 21
# 22
# 23
# 24
# 26
# 27
# 28
# 29
# 31
# 32
# 33
# 34
# 36
# 37
# 38
# 39
# 41
# 42
# 43
# 44
# 46
# 47
# 48
# 49
# 51
# 52
# 53
# 54
# 56
# 57
# 58
# 59
# 61
# 62
# 63
# 64
# 66
# 67
# 68
# 69
# 71
# 72
# 73
# 74
# 76
# 77
# 78
# 79
# 81
# 82
# 83
# 84
# 86
# 87
# 88
# 89
# 91
# 92
# 93
# 94
# 96
# 97
# 98
# 99

# %%
for number in range(1, 101):
    if number %7 == 0 and number %11 == 0:
        print("number divisible by 11 and 7:", number)
        break
# Out:
# number divisible by 11 and 7: 77

# %%
number = [10, 20, 30, 40, 50]
search_number = int(input("Enter a number to search: "))

for num in number:
    if num == search_number:
        print("Number found:", num)
        break
else:
    print("Number not found.")
# Out:
# Number not found.

# %%
name = ["Alice", "Bob", "Charlie", "David", "Eve"]

for position, name in enumerate(name, start=10):
    print(f"Position: {position}, Name: {name}")
# Out:
# Position: 10, Name: Alice
# Position: 11, Name: Bob
# Position: 12, Name: Charlie
# Position: 13, Name: David
# Position: 14, Name: Eve

# %%
for row in range(1, 6):
    print("*" * row)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for row in range(5, 0, -1):
    print("*" * row)
# Out:
# *****
# ****
# ***
# **
# *

# %%
for table in range(1, 11):
    print("\ntable of", table)

    for number in range(1, 11):
        print(f"{table} x {number} = {table * number}")
# Out:
# table of 1
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
#
# table of 2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
#
# table of 3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
#
# table of 4
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
#
# table of 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
#
# table of 6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
#
# table of 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# ...

# %%
for number in range(1, 201):
    if number % 3 == 0 and number % 5 == 0:
        print(number)
# Out:
# 15
# 30
# 45
# 60
# 75
# 90
# 105
# 120
# 135
# 150
# 165
# 180
# 195

# %%
number = [10, 20, 20,10 , 30,40, 50]
unique_numbers = []

for num in number:
    if num not in unique_numbers:
        unique_numbers.append(num)
print("original list:", number)
print("unique numbers:", unique_numbers)
# Out:
# original list: [10, 20, 20, 10, 30, 40, 50]
# unique numbers: [10, 20, 30, 40, 50]

# %%
number = [10, -4, 8, -2,0, 5, -1]

positive  = 0
negetive = 0
zero = 0

for num in number:
    if num > 0:
        positive += 1
    elif num < 0:
        negetive += 1
    else:
        zero += 1

print("Positive numbers:", positive)
print("Negative numbers:", negetive)
print("Zero numbers:", zero)
# Out:
# Positive numbers: 3
# Negative numbers: 3
# Zero numbers: 1

# %%
number = int(input("Enter a number to check if it is prime: "))
if number <= 1:
    print(number, "is not a prime number.")
else:
    is_prime = True
    for divisor in range(2, number):
        if number % divisor == 0:
            is_prime = False
            break
    if is_prime:
        print(number, "is a prime number.")
    else:
        print(number, "is not a prime number.")
# Out:
# 10 is not a prime number.

# %%
print("Prime numbers between 1 and 100:")
for num in range(1, 101):
    is_prime = True

    for divisor in range(2, num):
        if num % divisor == 0:
            is_prime = False
            break

    if is_prime:
        print(num, "is a prime number.")
# Out:
# Prime numbers between 1 and 100:
# 1 is a prime number.
# 2 is a prime number.
# 3 is a prime number.
# 5 is a prime number.
# 7 is a prime number.
# 11 is a prime number.
# 13 is a prime number.
# 17 is a prime number.
# 19 is a prime number.
# 23 is a prime number.
# 29 is a prime number.
# 31 is a prime number.
# 37 is a prime number.
# 41 is a prime number.
# 43 is a prime number.
# 47 is a prime number.
# 53 is a prime number.
# 59 is a prime number.
# 61 is a prime number.
# 67 is a prime number.
# 71 is a prime number.
# 73 is a prime number.
# 79 is a prime number.
# 83 is a prime number.
# 89 is a prime number.
# 97 is a prime number.
