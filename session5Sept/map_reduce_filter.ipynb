# %%
#lambda

l = lambda a,b : a+b
print(l(5, 3))
# Out:
# 8

# %%
b = lambda l :sum(l)
print(b([1, 2, 3, 4, 5]))
# Out:
# 15

# %%
l = [3,4,5,6,7,8,9]

# %%
(list(map(lambda x : x**2, l)))
# Out:
# [9, 16, 25, 36, 49, 64, 81]

# %%
#map

# %%
#reduce
#filter
