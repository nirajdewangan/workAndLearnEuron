# %%
l = [3,4,5,6,7,8,9 ]
print(l[20])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 l = [3,4,5,6,7,8,9 ]
# ----> 2 print(l[20])
#
# IndexError: list index out of range
